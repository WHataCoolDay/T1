# %%
#이거는 AI-hub데이터 확인해보는 페이지임
#뒤에 가서 설명 드림

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
with open("/content/drive/MyDrive/smart/Combined_LabelledData_18_역률평균.json", "r", encoding="utf-8") as f:
    content = f.read()
    json_data = json.loads(content)

# %%
for_soh = json_data['data'][:]

# %%
all_data = []
for i in for_soh:
  if i['ITEM_NAME'] == '역률평균':
    all_data.append(i)

# %%
data = pd.DataFrame(all_data)

# %%
data[data.LABEL_NAME == '경고'].describe()
# Out:
#         ITEM_VALUE
# count  3327.000000
# mean      0.582584
# std       0.060015
# min       0.051000
# 25%       0.562000
# 50%       0.568000
# 75%       0.578000
# max       0.918000

# %%
data[data.LABEL_NAME == '주의'].describe()
# Out:
#          ITEM_VALUE
# count  49573.000000
# mean       0.670137
# std        0.031889
# min        0.029000
# 25%        0.660000
# 50%        0.666000
# 75%        0.672000
# max        0.923000

# %%
data[data.LABEL_NAME == '정상'].describe()
# Out:
#        ITEM_VALUE
# count  380.000000
# mean     0.812288
# std      0.059000
# min      0.552000
# 25%      0.796000
# 50%      0.815000
# 75%      0.853250
# max      0.901000

# %%
# 보면 경고의 평균이 제일 낮긴 하지만
# 최대값은 주의일 때가 가장 높고 그 다음이 경고일 때임
# autoencoder에 넣을 때 정상과 주의의 평균으로 경고 데이터를 바꿔줬는데
# 이렇게 하면 안될 거 같은 생각이 들면서
# 또 하나 드는 생각은 
# 이 ITEM_VALUE로 정상, 주의, 경고를 구분하는 게 맞나 싶음
# 시간이 되시면 의견좀....
